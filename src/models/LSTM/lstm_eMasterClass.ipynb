# %%
import pandas as pd
import numpy as np

# %%
# importing data set from aemo.com.au/energy-systems/electricity/national-electricity-market-nem/data-nem
df = pd.read_csv('../csv/PRICE_AND_DEMAND_202301_NSW1.csv')
df.head()
# Out:
#   REGION       SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE
# 0   NSW1  2023/01/01 00:05:00      6906.63  140.40      TRADE
# 1   NSW1  2023/01/01 00:10:00      6854.28  133.96      TRADE
# 2   NSW1  2023/01/01 00:15:00      6856.32  120.00      TRADE
# 3   NSW1  2023/01/01 00:20:00      6796.27  118.99      TRADE
# 4   NSW1  2023/01/01 00:25:00      6805.55  118.99      TRADE

# %%
df.dtypes
# Out:
# REGION             object
# SETTLEMENTDATE     object
# TOTALDEMAND       float64
# RRP               float64
# PERIODTYPE         object
# dtype: object

# %%
df['Date_Time'] = pd.to_datetime(df['SETTLEMENTDATE'], dayfirst=True)
df['Day'] = df['Date_Time'].dt.day
df['Month'] = df['Date_Time'].dt.month
df['Year'] = df['Date_Time'].dt.year
df['Hour'] = df['Date_Time'].dt.hour
df['Minute'] = df['Date_Time'].dt.minute
df
# Out:
#      REGION       SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE  \
# 0      NSW1  2023/01/01 00:05:00      6906.63  140.40      TRADE
# 1      NSW1  2023/01/01 00:10:00      6854.28  133.96      TRADE
# 2      NSW1  2023/01/01 00:15:00      6856.32  120.00      TRADE
# 3      NSW1  2023/01/01 00:20:00      6796.27  118.99      TRADE
# 4      NSW1  2023/01/01 00:25:00      6805.55  118.99      TRADE
# ...     ...                  ...          ...     ...        ...
# 8923   NSW1  2023/01/31 23:40:00      7368.45  125.66      TRADE
# 8924   NSW1  2023/01/31 23:45:00      7306.86  120.06      TRADE
# 8925   NSW1  2023/01/31 23:50:00      7281.33  120.06      TRADE
# 8926   NSW1  2023/01/31 23:55:00      7300.71  120.06      TRADE
# 8927   NSW1  2023/02/01 00:00:00      7266.35  128.00      TRADE
#
#                Date_Time  Day  Month  Year  Hour  Minute
# 0    2023-01-01 00:05:00    1      1  2023     0       5
# 1    2023-01-01 00:10:00    1      1  2023     0      10
# 2    2023-01-01 00:15:00    1      1  2023     0      15
# 3    2023-01-01 00:20:00    1      1  2023     0      20
# 4    2023-01-01 00:25:00    1      1  2023     0      25
# ...                  ...  ...    ...   ...   ...     ...
# 8923 2023-01-31 23:40:00   31      1  2023    23      40
# 8924 2023-01-31 23:45:00   31      1  2023    23      45
# 8925 2023-01-31 23:50:00   31      1  2023    23      50
# 8926 2023-01-31 23:55:00   31      1  2023    23      55
# 8927 2023-02-01 00:00:00    1      2  2023     0       0
#
# [8928 rows x 11 columns]

# %%
df.dtypes
# Out:
# REGION                    object
# SETTLEMENTDATE            object
# TOTALDEMAND              float64
# RRP                      float64
# PERIODTYPE                object
# Date_Time         datetime64[ns]
# Day                        int64
# Month                      int64
# Year                       int64
# Hour                       int64
# Minute                     int64
# dtype: object

# %%
# Converting to numerics Reference: pandas.pydate.org/pandas-docs/stable/reference/api/pandas.to_numeric.html
df['Demand'] = pd.to_numeric(df['TOTALDEMAND'], errors='coerce')
df['Price'] = pd.to_numeric(df['RRP'], errors='coerce')

# %%
df.drop(['TOTALDEMAND', 'REGION', 'SETTLEMENTDATE', 'RRP', 'PERIODTYPE', 'Date_Time'], axis=1, inplace=True)
df
# Out:
#       Day  Month  Year  Hour  Minute   Demand   Price
# 0       1      1  2023     0       5  6906.63  140.40
# 1       1      1  2023     0      10  6854.28  133.96
# 2       1      1  2023     0      15  6856.32  120.00
# 3       1      1  2023     0      20  6796.27  118.99
# 4       1      1  2023     0      25  6805.55  118.99
# ...   ...    ...   ...   ...     ...      ...     ...
# 8923   31      1  2023    23      40  7368.45  125.66
# 8924   31      1  2023    23      45  7306.86  120.06
# 8925   31      1  2023    23      50  7281.33  120.06
# 8926   31      1  2023    23      55  7300.71  120.06
# 8927    1      2  2023     0       0  7266.35  128.00
#
# [8928 rows x 7 columns]

# %% [markdown]
# ## Transform the Data

# %%
x0 = []
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
y = []

# %%
for i in range (0, df.shape[0]-48):
    x0.append(df.iloc[i:i + 48, 0])
    x1.append(df.iloc[i:i + 48, 1])
    x2.append(df.iloc[i:i + 48, 2])
    x3.append(df.iloc[i:i + 48, 3])
    x4.append(df.iloc[i:i + 48, 4])
    x5.append(df.iloc[i:i + 48, 5])
    x6.append(df.iloc[i:i + 48, 6])
    y.append(df.iloc[i + 48, 6])

# %%
type(x5)
# Out:
# list

# %%
df.head(20)
# Out:
#     Day  Month  Year  Hour  Minute   Demand   Price
# 0     1      1  2023     0       5  6906.63  140.40
# 1     1      1  2023     0      10  6854.28  133.96
# 2     1      1  2023     0      15  6856.32  120.00
# 3     1      1  2023     0      20  6796.27  118.99
# 4     1      1  2023     0      25  6805.55  118.99
# 5     1      1  2023     0      30  6739.32  107.55
# 6     1      1  2023     0      35  6712.64  118.99
# 7     1      1  2023     0      40  6704.01  117.02
# 8     1      1  2023     0      45  6682.31  109.50
# 9     1      1  2023     0      50  6655.04  110.12
# 10    1      1  2023     0      55  6595.87  108.00
# 11    1      1  2023     1       0  6522.33  106.80
# 12    1      1  2023     1       5  6519.95  109.50
# 13    1      1  2023     1      10  6454.83  109.50
# 14    1      1  2023     1      15  6397.56  104.14
# 15    1      1  2023     1      20  6343.65  106.75
# 16    1      1  2023     1      25  6309.82  104.48
# 17    1      1  2023     1      30  6278.96  105.00
# 18    1      1  2023     1      35  6266.97  120.97
# 19    1      1  2023     1      40  6212.58  109.50

# %%
x0, x1, x2, x3, x4, x5, x6, y = np.array(x0), np.array(x1), np.array(x2), np.array(x3), np.array(x4), np.array(x5), np.array(x6), np.array(y)

# %%
y.shape
# Out:
# (8880,)

# %%
y = np.reshape(y, (len(y), 1))
y.shape
# Out:
# (8880, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
x0 = scaler.fit_transform(x0)
x1 = scaler.fit_transform(x1)
x2 = scaler.fit_transform(x2)
x3 = scaler.fit_transform(x3)
x4 = scaler.fit_transform(x4)
x5 = scaler.fit_transform(x5)
x6 = scaler.fit_transform(x6)
y = scaler.fit_transform(y)

# %%
x5
# Out:
# array([[0.37304588, 0.36509578, 0.36540558, ..., 0.2167546 , 0.21750329,
#         0.21908268],
#        [0.36509578, 0.36540558, 0.35628612, ..., 0.21750329, 0.21908268,
#         0.21220626],
#        [0.36540558, 0.35628612, 0.35769543, ..., 0.21908268, 0.21220626,
#         0.22493098],
#        ...,
#        [0.66393463, 0.66697647, 0.65258276, ..., 0.44306602, 0.44317992,
#         0.43382659],
#        [0.66697647, 0.65258276, 0.64663727, ..., 0.44317992, 0.43382659,
#         0.42994949],
#        [0.65258276, 0.64663727, 0.64593869, ..., 0.43382659, 0.42994949,
#         0.43289262]])

# %%
x5.shape
# Out:
# (8880, 48)

# %%
X = np.stack([x0, x1, x2, x3, x4, x5, x6], axis=2)

# %%
X.shape
# Out:
# (8880, 48, 7)

# %% [markdown]
# ## Build the LSTM Moded

# %%
X_train, X_test = X[:-480], X[-480:]
y_train, y_test = y[:-480], y[-480:]

# %%
X_train.shape[1], X_train.shape[2]
# Out:
# (48, 7)

# %%
# Importing keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras import optimizers

# %%
model = Sequential()
# set return requesnce = true, if we are going to have another LSTM Layer
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 48, 50)            11600
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 50)                2550
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 34,401
# Trainable params: 34,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

filepath = 'models/{epoch:02d}-{loss:.4f}-{val_loss:.4f}-{mae:.4f}-{val_mae:.4f}.hdf5'

callbacks = [EarlyStopping(monitor='val_loss', patience=20),
             ModelCheckpoint(filepath, monitor='loss', save_best_only=True, mode='min')]

# %%
optimizers.SGD(momentum=0.9)
model.compile(optimizer='SGD', loss='mse', metrics=['mae'])

# %%
model.fit(X_train, y_train, validation_split=0.2, epochs=1000, callbacks=callbacks, batch_size=16)
# Out:
# Epoch 1/100
# 420/420 [==============================] - 64s 116ms/step - loss: 3.8498e-04 - mae: 0.0143 - val_loss: 9.0608e-04 - val_mae: 0.0151
# Epoch 2/100
# 420/420 [==============================] - 30s 72ms/step - loss: 3.6620e-04 - mae: 0.0137 - val_loss: 9.0081e-04 - val_mae: 0.0147
# Epoch 3/100
# 420/420 [==============================] - 41s 99ms/step - loss: 3.5248e-04 - mae: 0.0133 - val_loss: 8.9491e-04 - val_mae: 0.0145
# Epoch 4/100
# 420/420 [==============================] - 42s 100ms/step - loss: 3.4200e-04 - mae: 0.0130 - val_loss: 8.9058e-04 - val_mae: 0.0143
# Epoch 5/100
# 420/420 [==============================] - 34s 81ms/step - loss: 3.3370e-04 - mae: 0.0128 - val_loss: 8.8445e-04 - val_mae: 0.0142
# Epoch 6/100
# 420/420 [==============================] - 33s 79ms/step - loss: 3.2625e-04 - mae: 0.0126 - val_loss: 8.9297e-04 - val_mae: 0.0142
# Epoch 7/100
# 420/420 [==============================] - 28s 67ms/step - loss: 3.1962e-04 - mae: 0.0124 - val_loss: 8.8889e-04 - val_mae: 0.0141
# Epoch 8/100
# 420/420 [==============================] - 25s 60ms/step - loss: 3.1461e-04 - mae: 0.0122 - val_loss: 8.6750e-04 - val_mae: 0.0138
# Epoch 9/100
# 420/420 [==============================] - 25s 59ms/step - loss: 3.1015e-04 - mae: 0.0121 - val_loss: 8.8427e-04 - val_mae: 0.0141
# Epoch 10/100
# 420/420 [==============================] - 32s 75ms/step - loss: 3.0634e-04 - mae: 0.0120 - val_loss: 8.8309e-04 - val_mae: 0.0141
# Epoch 11/100
# 420/420 [==============================] - 26s 62ms/step - loss: 3.0283e-04 - mae: 0.0119 - val_loss: 8.8104e-04 - val_mae: 0.0140
# Epoch 12/100
# 420/420 [==============================] - 25s 59ms/step - loss: 2.9965e-04 - mae: 0.0118 - val_loss: 8.7133e-04 - val_mae: 0.0139
# Epoch 13/100
# 420/420 [==============================] - 28s 66ms/step - loss: 2.9636e-04 - mae: 0.0118 - val_loss: 8.6928e-04 - val_mae: 0.0139
# Epoch 14/100
# 420/420 [==============================] - 25s 59ms/step - loss: 2.9402e-04 - mae: 0.0117 - val_loss: 8.5268e-04 - val_mae: 0.0136
# Epoch 15/100
# 420/420 [==============================] - 27s 65ms/step - loss: 2.9134e-04 - mae: 0.0117 - val_loss: 8.6441e-04 - val_mae: 0.0138
# Epoch 16/100
# 420/420 [==============================] - 26s 61ms/step - loss: 2.8896e-04 - mae: 0.0116 - val_loss: 8.4749e-04 - val_mae: 0.0135
# Epoch 17/100
# 420/420 [==============================] - 40s 95ms/step - loss: 2.8707e-04 - mae: 0.0115 - val_loss: 8.6157e-04 - val_mae: 0.0138
# Epoch 18/100
# 420/420 [==============================] - 28s 67ms/step - loss: 2.8486e-04 - mae: 0.0115 - val_loss: 8.5521e-04 - val_mae: 0.0137
# Epoch 19/100
# 420/420 [==============================] - 24s 58ms/step - loss: 2.8320e-04 - mae: 0.0115 - val_loss: 8.4490e-04 - val_mae: 0.0135
# Epoch 20/100
# 420/420 [==============================] - 30s 71ms/step - loss: 2.8135e-04 - mae: 0.0114 - val_loss: 8.4617e-04 - val_mae: 0.0136
# Epoch 21/100
# 420/420 [==============================] - 27s 63ms/step - loss: 2.7990e-04 - mae: 0.0114 - val_loss: 8.3862e-04 - val_mae: 0.0134
# Epoch 22/100
# 420/420 [==============================] - 24s 58ms/step - loss: 2.7803e-04 - mae: 0.0113 - val_loss: 8.2659e-04 - val_mae: 0.0132
# Epoch 23/100
# 420/420 [==============================] - 24s 58ms/step - loss: 2.7700e-04 - mae: 0.0113 - val_loss: 8.5241e-04 - val_mae: 0.0138
# Epoch 24/100
# 420/420 [==============================] - 27s 65ms/step - loss: 2.7577e-04 - mae: 0.0113 - val_loss: 8.2688e-04 - val_mae: 0.0132
# Epoch 25/100
# 420/420 [==============================] - 39s 94ms/step - loss: 2.7463e-04 - mae: 0.0112 - val_loss: 8.3636e-04 - val_mae: 0.0134
# Epoch 26/100
# 420/420 [==============================] - 47s 111ms/step - loss: 2.7364e-04 - mae: 0.0112 - val_loss: 8.2541e-04 - val_mae: 0.0132
# Epoch 27/100
# 420/420 [==============================] - 35s 84ms/step - loss: 2.7222e-04 - mae: 0.0112 - val_loss: 8.2427e-04 - val_mae: 0.0132
# Epoch 28/100
# 420/420 [==============================] - 32s 76ms/step - loss: 2.7131e-04 - mae: 0.0112 - val_loss: 8.1932e-04 - val_mae: 0.0131
# Epoch 29/100
# 420/420 [==============================] - 33s 78ms/step - loss: 2.7028e-04 - mae: 0.0111 - val_loss: 8.3471e-04 - val_mae: 0.0134
# Epoch 30/100
# 420/420 [==============================] - 32s 76ms/step - loss: 2.6897e-04 - mae: 0.0111 - val_loss: 8.1261e-04 - val_mae: 0.0130
# Epoch 31/100
# 420/420 [==============================] - 36s 86ms/step - loss: 2.6831e-04 - mae: 0.0111 - val_loss: 8.4153e-04 - val_mae: 0.0136
# Epoch 32/100
# 420/420 [==============================] - 34s 81ms/step - loss: 2.6739e-04 - mae: 0.0111 - val_loss: 8.1861e-04 - val_mae: 0.0131
# Epoch 33/100
# 420/420 [==============================] - 34s 81ms/step - loss: 2.6642e-04 - mae: 0.0111 - val_loss: 8.4613e-04 - val_mae: 0.0137
# Epoch 34/100
# 420/420 [==============================] - 41s 99ms/step - loss: 2.6571e-04 - mae: 0.0110 - val_loss: 8.2718e-04 - val_mae: 0.0133
# Epoch 35/100
# 420/420 [==============================] - 30s 71ms/step - loss: 2.6488e-04 - mae: 0.0110 - val_loss: 8.1549e-04 - val_mae: 0.0130
# Epoch 36/100
# 420/420 [==============================] - 50s 119ms/step - loss: 2.6405e-04 - mae: 0.0110 - val_loss: 8.2795e-04 - val_mae: 0.0133
# Epoch 37/100
# 420/420 [==============================] - 36s 87ms/step - loss: 2.6304e-04 - mae: 0.0110 - val_loss: 8.2797e-04 - val_mae: 0.0133
# Epoch 38/100
# 420/420 [==============================] - 25s 60ms/step - loss: 2.6278e-04 - mae: 0.0110 - val_loss: 8.2567e-04 - val_mae: 0.0132
# Epoch 39/100
# 420/420 [==============================] - 33s 78ms/step - loss: 2.6208e-04 - mae: 0.0109 - val_loss: 8.1514e-04 - val_mae: 0.0130
# Epoch 40/100
# 420/420 [==============================] - 37s 88ms/step - loss: 2.6111e-04 - mae: 0.0109 - val_loss: 8.1780e-04 - val_mae: 0.0130
# Epoch 41/100
# 420/420 [==============================] - 31s 74ms/step - loss: 2.6042e-04 - mae: 0.0109 - val_loss: 8.1949e-04 - val_mae: 0.0131
# Epoch 42/100
# 420/420 [==============================] - 39s 93ms/step - loss: 2.6002e-04 - mae: 0.0109 - val_loss: 8.1465e-04 - val_mae: 0.0129
# Epoch 43/100
# 420/420 [==============================] - 30s 71ms/step - loss: 2.5925e-04 - mae: 0.0109 - val_loss: 8.3346e-04 - val_mae: 0.0134
# Epoch 44/100
# 420/420 [==============================] - 44s 106ms/step - loss: 2.5887e-04 - mae: 0.0109 - val_loss: 8.1008e-04 - val_mae: 0.0128
# Epoch 45/100
# 420/420 [==============================] - 62s 147ms/step - loss: 2.5810e-04 - mae: 0.0108 - val_loss: 8.1783e-04 - val_mae: 0.0130
# Epoch 46/100
# 420/420 [==============================] - 59s 141ms/step - loss: 2.5756e-04 - mae: 0.0108 - val_loss: 8.2102e-04 - val_mae: 0.0131
# Epoch 47/100
# 420/420 [==============================] - 53s 126ms/step - loss: 2.5705e-04 - mae: 0.0108 - val_loss: 8.1865e-04 - val_mae: 0.0130
# Epoch 48/100
# 420/420 [==============================] - 49s 116ms/step - loss: 2.5649e-04 - mae: 0.0108 - val_loss: 8.1267e-04 - val_mae: 0.0129
# Epoch 49/100
# 420/420 [==============================] - 43s 104ms/step - loss: 2.5599e-04 - mae: 0.0108 - val_loss: 8.1835e-04 - val_mae: 0.0130
# Epoch 50/100
# 420/420 [==============================] - 42s 101ms/step - loss: 2.5535e-04 - mae: 0.0108 - val_loss: 8.1142e-04 - val_mae: 0.0128
# Epoch 51/100
# 420/420 [==============================] - 45s 106ms/step - loss: 2.5477e-04 - mae: 0.0107 - val_loss: 8.0994e-04 - val_mae: 0.0128
# Epoch 52/100
# 420/420 [==============================] - 70s 167ms/step - loss: 2.5437e-04 - mae: 0.0107 - val_loss: 8.2135e-04 - val_mae: 0.0131
# Epoch 53/100
# 420/420 [==============================] - 36s 86ms/step - loss: 2.5347e-04 - mae: 0.0107 - val_loss: 8.1881e-04 - val_mae: 0.0130
# Epoch 54/100
# 420/420 [==============================] - 35s 83ms/step - loss: 2.5317e-04 - mae: 0.0107 - val_loss: 8.0904e-04 - val_mae: 0.0128
# Epoch 55/100
# 420/420 [==============================] - 32s 75ms/step - loss: 2.5257e-04 - mae: 0.0107 - val_loss: 8.1561e-04 - val_mae: 0.0129
# Epoch 56/100
# 420/420 [==============================] - 34s 81ms/step - loss: 2.5238e-04 - mae: 0.0107 - val_loss: 8.1013e-04 - val_mae: 0.0128
# Epoch 57/100
# 420/420 [==============================] - 32s 77ms/step - loss: 2.5182e-04 - mae: 0.0106 - val_loss: 8.1010e-04 - val_mae: 0.0128
# Epoch 58/100
# 420/420 [==============================] - 33s 79ms/step - loss: 2.5099e-04 - mae: 0.0106 - val_loss: 8.1644e-04 - val_mae: 0.0129
# Epoch 59/100
# 420/420 [==============================] - 32s 77ms/step - loss: 2.5060e-04 - mae: 0.0106 - val_loss: 8.1313e-04 - val_mae: 0.0128
# Epoch 60/100
# 420/420 [==============================] - 32s 77ms/step - loss: 2.5044e-04 - mae: 0.0106 - val_loss: 8.1600e-04 - val_mae: 0.0129
# Epoch 61/100
# 420/420 [==============================] - 31s 75ms/step - loss: 2.4997e-04 - mae: 0.0106 - val_loss: 8.1942e-04 - val_mae: 0.0130
# Epoch 62/100
# 420/420 [==============================] - 31s 73ms/step - loss: 2.4949e-04 - mae: 0.0106 - val_loss: 8.1023e-04 - val_mae: 0.0128
# Epoch 63/100
# 420/420 [==============================] - 30s 73ms/step - loss: 2.4919e-04 - mae: 0.0106 - val_loss: 8.0468e-04 - val_mae: 0.0126
# Epoch 64/100
# 420/420 [==============================] - 31s 73ms/step - loss: 2.4863e-04 - mae: 0.0105 - val_loss: 8.0808e-04 - val_mae: 0.0127
# Epoch 65/100
# 420/420 [==============================] - 31s 74ms/step - loss: 2.4812e-04 - mae: 0.0105 - val_loss: 8.0657e-04 - val_mae: 0.0127
# Epoch 66/100
# 420/420 [==============================] - 43s 103ms/step - loss: 2.4772e-04 - mae: 0.0105 - val_loss: 8.0592e-04 - val_mae: 0.0127
# Epoch 67/100
# 420/420 [==============================] - 41s 98ms/step - loss: 2.4757e-04 - mae: 0.0105 - val_loss: 8.0413e-04 - val_mae: 0.0126
# Epoch 68/100
# 420/420 [==============================] - 30s 71ms/step - loss: 2.4710e-04 - mae: 0.0105 - val_loss: 8.0945e-04 - val_mae: 0.0127
# Epoch 69/100
# 420/420 [==============================] - 32s 77ms/step - loss: 2.4646e-04 - mae: 0.0105 - val_loss: 8.1002e-04 - val_mae: 0.0127
# Epoch 70/100
# 420/420 [==============================] - 30s 72ms/step - loss: 2.4564e-04 - mae: 0.0105 - val_loss: 7.9908e-04 - val_mae: 0.0125
# Epoch 71/100
# 420/420 [==============================] - 31s 74ms/step - loss: 2.4582e-04 - mae: 0.0105 - val_loss: 7.9848e-04 - val_mae: 0.0125
# Epoch 72/100
# 420/420 [==============================] - 31s 73ms/step - loss: 2.4549e-04 - mae: 0.0104 - val_loss: 8.1452e-04 - val_mae: 0.0128
# Epoch 73/100
# 420/420 [==============================] - 30s 71ms/step - loss: 2.4468e-04 - mae: 0.0104 - val_loss: 8.1233e-04 - val_mae: 0.0128
# Epoch 74/100
# 420/420 [==============================] - 31s 73ms/step - loss: 2.4428e-04 - mae: 0.0104 - val_loss: 7.9672e-04 - val_mae: 0.0124
# Epoch 75/100
# 420/420 [==============================] - 32s 76ms/step - loss: 2.4424e-04 - mae: 0.0104 - val_loss: 8.0174e-04 - val_mae: 0.0125
# Epoch 76/100
# 420/420 [==============================] - 34s 82ms/step - loss: 2.4384e-04 - mae: 0.0104 - val_loss: 8.0853e-04 - val_mae: 0.0127
# Epoch 77/100
# 420/420 [==============================] - 30s 70ms/step - loss: 2.4342e-04 - mae: 0.0104 - val_loss: 8.0306e-04 - val_mae: 0.0125
# Epoch 78/100
# 420/420 [==============================] - 37s 88ms/step - loss: 2.4301e-04 - mae: 0.0104 - val_loss: 8.0629e-04 - val_mae: 0.0126
# Epoch 79/100
# 420/420 [==============================] - 42s 100ms/step - loss: 2.4287e-04 - mae: 0.0104 - val_loss: 8.0596e-04 - val_mae: 0.0126
# Epoch 80/100
# 420/420 [==============================] - 41s 99ms/step - loss: 2.4223e-04 - mae: 0.0103 - val_loss: 8.0589e-04 - val_mae: 0.0126
# Epoch 81/100
# 420/420 [==============================] - 31s 75ms/step - loss: 2.4181e-04 - mae: 0.0103 - val_loss: 7.9599e-04 - val_mae: 0.0124
# Epoch 82/100
# 420/420 [==============================] - 42s 101ms/step - loss: 2.4158e-04 - mae: 0.0103 - val_loss: 8.0043e-04 - val_mae: 0.0125
# Epoch 83/100
# 420/420 [==============================] - 42s 99ms/step - loss: 2.4114e-04 - mae: 0.0103 - val_loss: 8.0462e-04 - val_mae: 0.0126
# Epoch 84/100
# 420/420 [==============================] - 41s 98ms/step - loss: 2.4072e-04 - mae: 0.0103 - val_loss: 7.9325e-04 - val_mae: 0.0123
# Epoch 85/100
# 420/420 [==============================] - 41s 98ms/step - loss: 2.4057e-04 - mae: 0.0103 - val_loss: 8.0267e-04 - val_mae: 0.0125
# Epoch 86/100
# 420/420 [==============================] - 42s 99ms/step - loss: 2.3976e-04 - mae: 0.0103 - val_loss: 8.0771e-04 - val_mae: 0.0126
# Epoch 87/100
# 420/420 [==============================] - 40s 96ms/step - loss: 2.3979e-04 - mae: 0.0103 - val_loss: 7.9778e-04 - val_mae: 0.0124
# Epoch 88/100
# 420/420 [==============================] - 40s 96ms/step - loss: 2.3939e-04 - mae: 0.0103 - val_loss: 8.0226e-04 - val_mae: 0.0125
# Epoch 89/100
# 420/420 [==============================] - 42s 99ms/step - loss: 2.3889e-04 - mae: 0.0102 - val_loss: 8.0479e-04 - val_mae: 0.0125
# Epoch 90/100
# 420/420 [==============================] - 42s 101ms/step - loss: 2.3881e-04 - mae: 0.0102 - val_loss: 8.0701e-04 - val_mae: 0.0126
# Epoch 91/100
# 420/420 [==============================] - 55s 130ms/step - loss: 2.3845e-04 - mae: 0.0102 - val_loss: 7.9671e-04 - val_mae: 0.0123
# Epoch 92/100
# 420/420 [==============================] - 53s 125ms/step - loss: 2.3793e-04 - mae: 0.0102 - val_loss: 7.9717e-04 - val_mae: 0.0123
# Epoch 93/100
# 420/420 [==============================] - 56s 133ms/step - loss: 2.3764e-04 - mae: 0.0102 - val_loss: 7.9810e-04 - val_mae: 0.0124
# Epoch 94/100
# 420/420 [==============================] - 48s 114ms/step - loss: 2.3725e-04 - mae: 0.0102 - val_loss: 7.9884e-04 - val_mae: 0.0124
# Epoch 95/100
# 420/420 [==============================] - 42s 100ms/step - loss: 2.3670e-04 - mae: 0.0102 - val_loss: 8.0049e-04 - val_mae: 0.0124
# Epoch 96/100
# 420/420 [==============================] - 42s 101ms/step - loss: 2.3662e-04 - mae: 0.0102 - val_loss: 7.9729e-04 - val_mae: 0.0123
# Epoch 97/100
# 420/420 [==============================] - 43s 103ms/step - loss: 2.3605e-04 - mae: 0.0102 - val_loss: 7.9822e-04 - val_mae: 0.0123
# Epoch 98/100
# 420/420 [==============================] - 42s 100ms/step - loss: 2.3563e-04 - mae: 0.0101 - val_loss: 7.9401e-04 - val_mae: 0.0123
# Epoch 99/100
# 420/420 [==============================] - 42s 100ms/step - loss: 2.3520e-04 - mae: 0.0101 - val_loss: 7.9455e-04 - val_mae: 0.0123
# Epoch 100/100
# 420/420 [==============================] - 42s 100ms/step - loss: 2.3515e-04 - mae: 0.0101 - val_loss: 8.0777e-04 - val_mae: 0.0126

# %%
MSE, MAE = model.evaluate(X_test, y_test)
print(MSE, MAE)
# Out:
# 15/15 [==============================] - 13s 41ms/step - loss: 2.4822e-04 - mae: 0.0117
# 0.0002482157724443823 0.011682985350489616

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
predictions
# Out:
# 15/15 [==============================] - 8s 22ms/step
# array([[119.93175 ],
#        [121.94498 ],
#        [121.648155],
#        [121.500725],
#        [121.3842  ],
#        [121.32103 ],
#        [121.48083 ],
#        [121.87213 ],
#        [122.429214],
#        [123.098526],
#        [121.848145],
#        [119.52136 ],
#        [120.813675],
#        [123.682556],
#        [123.35791 ],
#        [123.045166],
#        [122.975685],
#        [123.175735],
#        [123.80277 ],
#        [124.41832 ],
#        [124.911026],
#        [125.25636 ],
#        [123.830055],
#        [121.49178 ],
#        [122.91991 ],
#        [125.60056 ],
#        [125.12815 ],
#        [124.27485 ],
#        [123.853775],
#        [123.991135],
#        [124.31584 ],
#        [124.7269  ],
#        [125.15476 ],
#        [125.41093 ],
#        [124.0541  ],
#        [121.208405],
#        [122.35395 ],
#        [123.94887 ],
#        [122.5913  ],
#        [121.12931 ],
#        [120.024414],
#        [119.06058 ],
#        [118.05749 ],
#        [117.01052 ],
#        [116.07    ],
#        [115.23155 ],
#        [114.52636 ],
#        [111.153015],
#        [112.05685 ],
#        [112.612045],
#        [111.60715 ],
#        [111.01163 ],
#        [110.84409 ],
#        [110.97036 ],
#        [111.47785 ],
#        [112.21436 ],
#        [113.00449 ],
#        [113.738106],
#        [113.99065 ],
#        [111.19931 ],
#        [112.716545],
#        [114.911476],
#        [114.62037 ],
#        [114.58066 ],
#        [114.81377 ],
#        [115.39121 ],
#        [116.20977 ],
#        [117.204185],
#        [117.87437 ],
#        [118.86442 ],
#        [117.84736 ],
#        [115.60645 ],
#        [117.044525],
#        [120.00191 ],
#        [120.90043 ],
#        [121.03174 ],
#        [121.58519 ],
#        [122.50797 ],
#        [123.61294 ],
#        [124.64203 ],
#        [125.78872 ],
#        [126.26328 ],
#        [124.609634],
#        [122.53412 ],
#        [123.81588 ],
#        [126.79114 ],
#        [128.74307 ],
#        [128.64711 ],
#        [128.60599 ],
#        [128.85194 ],
#        [129.36964 ],
#        [130.00562 ],
#        [130.776   ],
#        [129.79286 ],
#        [128.04152 ],
#        [125.860016],
#        [126.71903 ],
#        [128.94736 ],
#        [131.45471 ],
#        [131.52217 ],
#        [131.65846 ],
#        [131.81758 ],
#        [132.02322 ],
#        [132.26192 ],
#        [132.39282 ],
#        [130.66405 ],
#        [128.57104 ],
#        [125.982254],
#        [126.8209  ],
#        [129.82204 ],
#        [132.75555 ],
#        [133.21964 ],
#        [133.19786 ],
#        [133.45805 ],
#        [133.73654 ],
#        [134.01636 ],
#        [134.26042 ],
#        [132.18799 ],
#        [129.74542 ],
#        [127.15119 ],
#        [128.5611  ],
#        [132.11838 ],
#        [134.58527 ],
#        [134.2408  ],
#        [134.1017  ],
#        [133.92618 ],
#        [133.77847 ],
#        [133.5848  ],
#        [133.34409 ],
#        [131.41412 ],
#        [128.58717 ],
#        [125.299576],
#        [126.597534],
#        [130.30331 ],
#        [133.12663 ],
#        [133.30861 ],
#        [133.4242  ],
#        [133.37285 ],
#        [133.282   ],
#        [132.98282 ],
#        [132.57533 ],
#        [131.03001 ],
#        [128.08748 ],
#        [124.25059 ],
#        [125.75552 ],
#        [129.68199 ],
#        [132.06703 ],
#        [131.99432 ],
#        [131.6043  ],
#        [130.95018 ],
#        [129.54893 ],
#        [128.28732 ],
#        [127.225716],
#        [125.35938 ],
#        [121.43527 ],
#        [117.250084],
#        [118.575195],
#        [121.76704 ],
#        [123.249115],
#        [122.53546 ],
#        [121.09457 ],
#        [119.71194 ],
#        [118.32689 ],
#        [117.264   ],
#        [115.87223 ],
#        [114.02458 ],
#        [110.29864 ],
#        [106.391594],
#        [108.11063 ],
#        [111.95255 ],
#        [113.87956 ],
#        [113.60478 ],
#        [112.88252 ],
#        [111.76923 ],
#        [110.217865],
#        [108.66757 ],
#        [107.287094],
#        [105.51424 ],
#        [101.68293 ],
#        [ 97.78502 ],
#        [ 99.6322  ],
#        [103.48334 ],
#        [104.997475],
#        [104.74998 ],
#        [103.94412 ],
#        [102.676605],
#        [101.2419  ],
#        [ 99.81969 ],
#        [ 98.40312 ],
#        [ 96.575226],
#        [ 92.58835 ],
#        [ 88.50813 ],
#        [ 94.334465],
#        [ 97.95047 ],
#        [ 99.10401 ],
#        [ 99.51339 ],
#        [ 99.36649 ],
#        [ 98.86814 ],
#        [ 98.14306 ],
#        [ 97.89637 ],
#        [ 98.68039 ],
#        [100.30285 ],
#        [ 99.76734 ],
#        [ 99.03695 ],
#        [ 97.95114 ],
#        [ 96.61239 ],
#        [ 95.242195],
#        [ 94.00734 ],
#        [ 92.4055  ],
#        [ 91.17609 ],
#        [ 90.29726 ],
#        [ 89.4502  ],
#        [ 88.50981 ],
#        [ 87.373474],
#        [ 86.0991  ],
#        [ 84.81841 ],
#        [ 84.729576],
#        [ 84.50244 ],
#        [ 84.074715],
#        [ 83.43155 ],
#        [ 82.37437 ],
#        [ 81.06942 ],
#        [ 79.81709 ],
#        [ 79.133606],
#        [ 78.58224 ],
#        [ 78.17279 ],
#        [ 78.000755],
#        [ 78.10801 ],
#        [ 78.76992 ],
#        [ 79.207794],
#        [ 79.024   ],
#        [ 78.288574],
#        [ 77.05963 ],
#        [ 76.03692 ],
#        [ 75.56854 ],
#        [ 75.3998  ],
#        [ 75.27306 ],
#        [ 75.38078 ],
#        [ 75.747154],
#        [ 76.29887 ],
#        [ 78.00513 ],
#        [ 78.533585],
#        [ 78.15075 ],
#        [ 77.83941 ],
#        [ 77.54535 ],
#        [ 77.302086],
#        [ 77.4848  ],
#        [ 78.19624 ],
#        [ 79.04141 ],
#        [ 79.975815],
#        [ 81.1264  ],
#        [ 82.54976 ],
#        [ 83.578445],
#        [ 83.96357 ],
#        [ 84.76929 ],
#        [ 85.566345],
#        [ 85.88138 ],
#        [ 86.66989 ],
#        [ 87.76679 ],
#        [ 89.108025],
#        [ 90.85447 ],
#        [ 92.52068 ],
#        [ 93.84337 ],
#        [ 95.10571 ],
#        [ 96.31362 ],
#        [ 97.41999 ],
#        [ 98.61379 ],
#        [ 99.42724 ],
#        [100.367966],
#        [101.393295],
#        [102.211716],
#        [103.098816],
#        [103.95789 ],
#        [104.86052 ],
#        [105.624985],
#        [105.532585],
#        [105.6489  ],
#        [105.846535],
#        [105.41633 ],
#        [105.16782 ],
#        [105.17804 ],
#        [105.15237 ],
#        [105.39462 ],
#        [105.813   ],
#        [106.40389 ],
#        [107.05109 ],
#        [107.237434],
#        [106.721405],
#        [106.64789 ],
#        [106.53419 ],
#        [105.998276],
#        [105.54629 ],
#        [105.00459 ],
#        [104.464645],
#        [104.01515 ],
#        [103.593544],
#        [103.55174 ],
#        [103.47507 ],
#        [103.45256 ],
#        [102.75503 ],
#        [103.24901 ],
#        [103.89567 ],
#        [103.6647  ],
#        [102.86933 ],
#        [102.36567 ],
#        [102.18941 ],
#        [102.32905 ],
#        [102.66417 ],
#        [103.208626],
#        [103.77229 ],
#        [104.29403 ],
#        [103.53132 ],
#        [103.93357 ],
#        [103.799644],
#        [103.31493 ],
#        [102.69139 ],
#        [102.01825 ],
#        [101.745895],
#        [101.76807 ],
#        [102.09385 ],
#        [102.530174],
#        [102.8817  ],
#        [102.92921 ],
#        [102.640045],
#        [104.0253  ],
#        [104.285225],
#        [104.01166 ],
#        [103.360695],
#        [102.85401 ],
#        [102.71928 ],
#        [102.466805],
#        [101.92787 ],
#        [101.42979 ],
#        [100.995544],
#        [100.04453 ],
#        [ 98.61453 ],
#        [ 98.651085],
#        [ 97.98118 ],
#        [ 97.26295 ],
#        [ 95.933945],
#        [ 94.5745  ],
#        [ 93.5362  ],
#        [ 92.81629 ],
#        [ 93.99349 ],
#        [ 94.62745 ],
#        [ 94.98926 ],
#        [ 95.22761 ],
#        [ 95.106514],
#        [ 96.44675 ],
#        [ 96.85202 ],
#        [ 96.55251 ],
#        [ 95.710304],
#        [ 94.825356],
#        [ 94.21552 ],
#        [ 93.82858 ],
#        [ 94.98737 ],
#        [ 95.62819 ],
#        [ 95.65016 ],
#        [ 95.53021 ],
#        [ 95.00498 ],
#        [ 96.14334 ],
#        [ 97.19534 ],
#        [ 98.97969 ],
#        [100.6076  ],
#        [101.051186],
#        [102.63736 ],
#        [104.79923 ],
#        [105.92026 ],
#        [107.077095],
#        [108.44783 ],
#        [109.13427 ],
#        [108.26713 ],
#        [111.12875 ],
#        [112.689995],
#        [113.119675],
#        [113.23008 ],
#        [113.69187 ],
#        [114.24473 ],
#        [114.40956 ],
#        [114.98305 ],
#        [115.991035],
#        [116.91765 ],
#        [116.10884 ],
#        [114.01712 ],
#        [116.0452  ],
#        [119.66194 ],
#        [119.86919 ],
#        [119.95493 ],
#        [120.348045],
#        [121.21687 ],
#        [122.626854],
#        [123.7095  ],
#        [124.7441  ],
#        [125.08487 ],
#        [123.05088 ],
#        [120.46619 ],
#        [122.07131 ],
#        [125.35246 ],
#        [127.419044],
#        [127.78024 ],
#        [129.02249 ],
#        [130.58986 ],
#        [131.6719  ],
#        [132.80475 ],
#        [134.50208 ],
#        [134.62518 ],
#        [133.8036  ],
#        [132.54266 ],
#        [133.99606 ],
#        [137.86433 ],
#        [141.3591  ],
#        [142.02869 ],
#        [142.38403 ],
#        [142.9192  ],
#        [143.45049 ],
#        [143.73447 ],
#        [143.84898 ],
#        [142.15663 ],
#        [139.45212 ],
#        [136.8718  ],
#        [138.2268  ],
#        [141.37067 ],
#        [143.69577 ],
#        [144.06403 ],
#        [144.23955 ],
#        [144.35056 ],
#        [144.01134 ],
#        [143.49094 ],
#        [142.80846 ],
#        [140.73065 ],
#        [137.28816 ],
#        [133.11023 ],
#        [133.53494 ],
#        [136.34508 ],
#        [137.80077 ],
#        [136.82852 ],
#        [135.8345  ],
#        [134.76953 ],
#        [132.9878  ],
#        [131.22704 ],
#        [129.82498 ],
#        [127.299904],
#        [123.037575],
#        [118.9966  ],
#        [119.899155],
#        [123.24347 ],
#        [125.008736],
#        [124.10477 ],
#        [122.56294 ],
#        [120.86226 ],
#        [119.124886],
#        [117.7307  ],
#        [116.20816 ],
#        [113.95288 ],
#        [110.00282 ],
#        [106.15761 ],
#        [107.19752 ],
#        [110.7896  ],
#        [112.60075 ],
#        [112.14185 ],
#        [111.00739 ],
#        [109.464355],
#        [107.516914],
#        [105.59393 ],
#        [103.72525 ],
#        [101.46372 ],
#        [ 97.350845],
#        [ 93.491646],
#        [ 94.89168 ],
#        [ 98.66264 ],
#        [100.24714 ],
#        [100.066574],
#        [ 99.27483 ],
#        [ 98.06269 ],
#        [ 96.54129 ],
#        [ 94.882675],
#        [ 93.19207 ],
#        [ 91.30867 ],
#        [ 87.14943 ],
#        [ 83.266106]], dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.figure(figsize=(24,12))
plt.title('30 Minutes ahead Electricity Price Forecasting')
plt.xlabel('Step (30 minutes)')
plt.ylabel('Electricity Price (AUD)')
plt.plot(predictions)
plt.plot(scaler.inverse_transform(y_test))
plt.legend(['Forecast', 'Actual'])
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(24,12))
plt.title('30 Minutes ahead Electricity Price Forecasting')
plt.xlabel('Step (30 minutes)')
plt.ylabel('Electricity Price (AUD)')
plt.plot(predictions[350:450])
plt.plot(scaler.inverse_transform(y_test)[350:450])
plt.legend(['Forecast', 'Actual'])
plt.show()
plt.savefig('0 Minutes ahead Electricity Price Forecasting.png')
