# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## 1. Import the needed Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.	Import the tools needed in Sklearn

# %%
import sklearn
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.tree import (DecisionTreeClassifier,plot_tree)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 3. Call the data

# %%
iris=pd.read_csv("../../data/Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## 4. Define Feature and  Target

# %%
feature=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
target=['Species']
x=iris[feature]
y=iris[target]

# %% [markdown]
# ## 5.	Split dataset into training and validation set

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.25, random_state=42)
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 4              5.0           3.6            1.4           0.2
# 32             5.2           4.1            1.5           0.1
# 142            5.8           2.7            5.1           1.9
# 85             6.0           3.4            4.5           1.6
# 86             6.7           3.1            4.7           1.5
# ..             ...           ...            ...           ...
# 71             6.1           2.8            4.0           1.3
# 106            4.9           2.5            4.5           1.7
# 14             5.8           4.0            1.2           0.2
# 92             5.8           2.6            4.0           1.2
# 102            7.1           3.0            5.9           2.1
#
# [112 rows x 4 columns]

# %% [markdown]
# ## 6.	Train Decision Tree Model
#
# (you can check the meaning of each parameter here: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html )

# %%
dt_model=DecisionTreeClassifier(criterion='entropy', max_depth=2)
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2)

# %% [markdown]
# ## 7.	Test Model

# %%
print("Train data accuracy:", accuracy_score(y_true=y_train, y_pred=dt_model.predict(x_train)))
print("Test data accuracy:", accuracy_score(y_true=y_test, y_pred=dt_model.predict(x_test)))
# Out:
# Train data accuracy: 0.9464285714285714
# Test data accuracy: 0.9736842105263158

# %% [markdown]
# ## 8.	Plot Decision Tree

# %%
plt.figure(figsize=(10,10))
plot_tree(dt_model, filled=True, class_names=True)
plt.title("Iris Decision Tree Classifier")
plt.show()

plt.savefig('../../visualizations/iris_decision tree.png')
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 9.	Predict New Dataset

# %%
x_new=[[5.9,3.0,5.1,1.8]]
print(dt_model.predict(x_new))
print(dt_model.predict_proba(x_new))
# Out:
# ['Iris-virginica']
# [[0.         0.11904762 0.88095238]]
# c:\Users\aky\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\aky\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
